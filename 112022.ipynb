# %% [markdown]
# <a href="https://colab.research.google.com/github/Englishson0909/2024-2/blob/main/112022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd  # Import pandas library

# Example DataFrame
data = {
    'Word': ['apple', 'banana', 'cherry'],
    'Meaning': [
        'A round fruit with red, green, or yellow skin, and a crisp white interior.',
        'A long, curved fruit with a soft, starchy interior, typically yellow when ripe.',
        'A small, round, red fruit with a juicy interior and a pit in the center.'
    ]
}

df = pd.DataFrame(data)

print(df)  # Display the DataFrame
# Out:
#      Word                                            Meaning
# 0   apple  A round fruit with red, green, or yellow skin,...
# 1  banana  A long, curved fruit with a soft, starchy inte...
# 2  cherry  A small, round, red fruit with a juicy interio...

# %%
import pandas as pd  # Import pandas library

# Example DataFrame
data = {
    'Word': ['Basic', 'Past', 'Past participle'],
    'Meaning': [
        'A basci form of Verb.',
        'The past form of verb.',
        'The past participle form of verb.'
    ]
}

df = pd.DataFrame(data)

print(df)  # Display the DataFrame
# Out:
#               Word                            Meaning
# 0            Basic              A basci form of Verb.
# 1             Past             The past form of verb.
# 2  Past participle  The past participle form of verb.

# %%
from google.colab import files

uploaded = files.upload()  # Upload a CSV file manually
# Out:
#      <input type="file" id="files-03c43c6f-63fd-4167-bb7a-6db0aaf6e88c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-03c43c6f-63fd-4167-bb7a-6db0aaf6e88c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
type(uploaded)
# Out:
# dict

# %%
df1 = pd.read_csv('sample1120.csv')

# %%
df1
# Out:
#    Entry Present    Past Past participle
# 0      1    come    came            come
# 1      2     run     ran             run
# 2      3    kick  kicked          kicked

# %%
url="https://raw.githubusercontent.com/Englishson0909/2024-2/refs/heads/main/sample1120.csv"
df2=pd.read_csv(url)
df2
# Out:
#    Entry Present    Past Past participle
# 0      1    come    came            come
# 1      2     run     ran             run
# 2      3    kick  kicked          kicked

# %%
df2.to_csv('output.csv', index=False)
from google.colab import files
files.download('output.csv')  # Download the CSV file

# %%
df2.to_csv('output.csv', index=False)

# %%
df2.head

# %%
print(df2['Present'])  # Access the 'Word' column
# Out:
# 0    come
# 1     run
# 2    kick
# Name: Present, dtype: object

# %%
print(df2['Past participle'])  # Access the 'Word' column
# Out:
# 0      come
# 1       run
# 2    kicked
# Name: Past participle, dtype: object

# %%
df2['Past']
# Out:
# 0      came
# 1       ran
# 2    kicked
# Name: Past, dtype: object

# %%
df1
# Out:
#    Entry Present    Past Past participle
# 0      1    come    came            come
# 1      2     run     ran             run
# 2      3    kick  kicked          kicked

# %%
df1['Entry']
# Out:
# 0    1
# 1    2
# 2    3
# Name: Entry, dtype: int64

# %%
filtered = df2[df2['Present'] == 'kick']  # Filter rows where 'Word' is 'apple'
print(filtered)
# Out:
#    Entry Present    Past Past participle
# 2      3    kick  kicked          kicked

# %%
df['Length'] = df['Word'].apply(len)  # Add a column with word lengths
print(df)
# Out:
#               Word                            Meaning  Length
# 0            Basic              A basci form of Verb.       5
# 1             Past             The past form of verb.       4
# 2  Past participle  The past participle form of verb.      15

# %%
df['Length'] = df['Word'].apply(len)  # Add a column with word lengths
print(df)

# %%
df3 = df.sort_values(by='Length', ascending=False)  # Sort by the 'Length' column
print(df2)
# Out:
#               Word                            Meaning  Length
# 1             Past             The past form of verb.       4
# 0            Basic              A basci form of Verb.       5
# 2  Past participle  The past participle form of verb.      15

# %% [markdown]
# 1. create an exfile; test.xlsx
# 2. input fowllowing data
# Name |Korean|English
# 엑셀로 만들기
# 3. CSV 파일로 저장:'Midterm.csv'
# 4. coding to read 'Midterm.csv., display the first 5 rows and display the last

# %%
url4="https://raw.githubusercontent.com/Englishson0909/2024-2/refs/heads/main/Midterm.csv"
df4=pd.read_csv(url4)
df4
# Out:
#       Name  Korean  English
# 0    Jenny      80       100
# 1     John      50        60
# 2  Jiyoung      50        40
# 3     Jack      80        50
# 4      Tom      70        70
# 5      Ann     100        95

# %%
filtered = df4[df4['Name'] == 'Jenny']  # Filter rows where 'Word' is 'apple'
print(filtered)
# Out:
#     Name  Korean  English
# 0  Jenny      80       100

# %%
filtered = df4[df4['Name'] == 'Ann']  # Filter rows where 'Word' is 'apple'
print(filtered)
# Out:
#   Name  Korean  English
# 5  Ann     100        95

# %%
df4 = df4.sort_values(by='Korean', ascending=False)  # Sort by the 'Length' column
print(df4)
# Out:
#       Name  Korean  English
# 5      Ann     100        95
# 0    Jenny      80       100
# 3     Jack      80        50
# 4      Tom      70        70
# 1     John      50        60
# 2  Jiyoung      50        40

# %%
df4 = df4.sort_values(by='English', ascending=False)  # Sort by the 'Length' column
print(df4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-f82648bbd671> in <cell line: 1>()
# ----> 1 df4 = df4.sort_values(by='English', ascending=False)  # Sort by the 'Length' column
#       2 print(df4)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/Englishson0909/2024-2/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gradio
# !pip install gtts

import gradio as gr
import pandas as pd
import random
import os
import tempfile
from gtts import gTTS

# Load the irregular verbs data
data_url = "https://github.com/Hansukson/Application2/raw/main/irregular_verbs%20(1).csv"
verbs_df = pd.read_csv(data_url)

# Extract verbs data into a dictionary
verbs_data = verbs_df.set_index("present")[['past', 'p.p']].to_dict(orient="index")

def tts_play(verb_forms):
    """Generate speech for the verb forms: present, pastt, p.p."""
    tts_text = f"{verb_forms[0]}, {verb_forms[1]}, {verb_forms[2]}"
    temp_audio_file = tempfile.NamedTemporaryFile(delete=False, suffix=".mp3")
    tts = gTTS(tts_text)
    tts.save(temp_audio_file.name)
    return temp_audio_file.name

def start_game(name):
    """Welcome message when the game starts."""
    return f"Welcome, {name}! Click 'Show me a Verb' to begin.", ""

current_verb = ""
correct_count = 0
attempt_count = 0


def show_random_verb():
    """Select a random present tense verb."""
    global current_verb
    current_verb = random.choice(list(verbs_data.keys()))
    return current_verb, ""


def check_answer(user_past, user_past_participle):
    """Check if the student's answer is correct or not."""
    global correct_count, attempt_count, current_verb

    attempt_count += 1
    correct_past, correct_past_participle = verbs_data[current_verb]['Past Tense'], verbs_data[current_verb]['Past Participle']

    if user_past.lower() == correct_past.lower() and user_past_participle.lower() == correct_past_participle.lower():
        correct_count += 1
        feedback = random.choice(["Amazing!", "Wonderful!", "Nice Job!"]) + f" The correct answer is: {correct_past}, {correct_past_participle}."
        audio_file = tts_play([current_verb, correct_past, correct_past_participle])
        return feedback, f"Your Score: {correct_count} / {attempt_count}", audio_file
    else:
        feedback = f"Try again! The correct answer is: {correct_past}, {correct_past_participle}."
        audio_file = tts_play([current_verb, correct_past, correct_past_participle])
        return feedback, f"Your Score: {correct_count} / {attempt_count}", audio_file

# Gradio Interface
def verb_game():
    with gr.Blocks() as app:
        gr.Markdown("""# VerbMaster: Learn Irregular Verbs!
        This app helps you practice the Past and Past Participle forms of irregular verbs.
        """)

        with gr.Row():
            name_input = gr.Textbox(label="Enter Your Name")
            welcome_output = gr.Textbox(label="Welcome Message", interactive=False)
            start_button = gr.Button("Start")

        start_button.click(start_game, inputs=name_input, outputs=welcome_output)

        with gr.Row():
            random_verb_button = gr.Button("Show me a Verb")
            present_verb_output = gr.Textbox(label="present", interactive=False)

        with gr.Row():
            user_past_input = gr.Textbox(label="Enter past")
            user_pp_input = gr.Textbox(label="Enter p.p")
            feedback_output = gr.Textbox(label="Feedback", interactive=False)
            score_output = gr.Textbox(label="Score", interactive=False)
            submit_button = gr.Button("Submit")
            tts_output = gr.Audio(label="Audio Feedback")

        random_verb_button.click(show_random_verb, inputs=None, outputs=[present_verb_output, feedback_output])
        submit_button.click(check_answer, inputs=[user_past_input, user_pp_input], outputs=[feedback_output, score_output, tts_output])

    return app

# Launch the app
app = verb_game()
app.launch()
# Out:
# Requirement already satisfied: gradio in /usr/local/lib/python3.10/dist-packages (5.9.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.115.6)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio) (0.4.0)
# Requirement already satisfied: gradio-client==1.5.2 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.5.2)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.25.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.26.5)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.1.5)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.10.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (11.0.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.10.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.0.19)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.8.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.41.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.34.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.5.2->gradio) (2024.10.0)
# Requirement already satisfied: websockets<15.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.5.2->gradio) (14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.25.1->gradio) (3.16.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.25.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.25.1->gradio) (4.66.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (2.27.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.25.1->gradio) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.25.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: gtts in /usr/local/lib/python3.10/dist-packages (2.5.4)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gtts) (2.32.3)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gtts) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2024.8.30)
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://6d9cefedcbcdb62879.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://6d9cefedcbcdb62879.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import pandas as pd
import random
import os
import tempfile
from gtts import gTTS

# Load the irregular verbs data
data_url = "https://github.com/Hansukson/Application2/raw/main/irregular_verbs%20(1).csv"
verbs_df = pd.read_csv(data_url)

# Extract verbs data into a dictionary
verbs_data = verbs_df.set_index("present")[['past', 'p.p']].to_dict(orient="index")

def tts_play(verb_forms):
    """Generate speech for the verb forms: present, past, p.p."""
    tts_text = f"{verb_forms[0]}, {verb_forms[1]}, {verb_forms[2]}"
    temp_audio_file = tempfile.gettempdir() + "/verb_audio.mp3"
    tts = gTTS(tts_text)
    tts.save(temp_audio_file)
    return temp_audio_file

def start_game(name):
    """Welcome message when the game starts."""
    return f"Welcome, {name}! Click 'Show me a Verb' to begin.", ""

current_verb = ""
correct_count = 0
attempt_count = 0

def show_random_verb():
    """Select a random present tense verb."""
    global current_verb
    current_verb = random.choice(list(verbs_data.keys()))
    return current_verb, ""

def check_answer(user_past, user_past_participle):
    """Check if the student's answer is correct or not."""
    global correct_count, attempt_count, current_verb

    attempt_count += 1
    correct_past, correct_past_participle = verbs_data[current_verb]['Past Tense'], verbs_data[current_verb]['Past Participle']

    if user_past.lower() == correct_past.lower() and user_past_participle.lower() == correct_past_participle.lower():
        correct_count += 1
        feedback = random.choice(["Amazing!", "Wonderful!", "Nice Job!"]) + f" The correct answer is: {correct_past}, {correct_past_participle}."
        audio_file = tts_play([current_verb, correct_past, correct_past_participle])
        return feedback, f"Your Score: {correct_count} / {attempt_count}", audio_file
    else:
        feedback = f"Try again! The correct answer is: {correct_past}, {correct_past_participle}."
        audio_file = tts_play([current_verb, correct_past, correct_past_participle])
        return feedback, f"Your Score: {correct_count} / {attempt_count}", audio_file

# Gradio Interface
def verb_game():
    with gr.Blocks() as app:
        gr.Markdown("""# VerbMaster: Learn Irregular Verbs!
        This app helps you practice the Past and Past Participle forms of irregular verbs.
        """)

        name_input = gr.Textbox(label="Enter Your Name")
        welcome_output = gr.Textbox(label="Welcome Message", interactive=False)
        start_button = gr.Button("Start")
        start_button.click(start_game, inputs=name_input, outputs=welcome_output)

        gr.Markdown("---")
        random_verb_button = gr.Button("Show me a Verb")
        present_verb_output = gr.Textbox(label="Present Verb", interactive=False)
        random_verb_button.click(show_random_verb, inputs=None, outputs=[present_verb_output, welcome_output])

        gr.Markdown("---")
        user_past_input = gr.Textbox(label="Enter Past Form")
        user_pp_input = gr.Textbox(label="Enter Past Participle")
        feedback_output = gr.Textbox(label="Feedback", interactive=False)
        score_output = gr.Textbox(label="Score", interactive=False)
        tts_output = gr.Audio(label="Audio Feedback")
        submit_button = gr.Button("Submit")
        submit_button.click(check_answer, inputs=[user_past_input, user_pp_input], outputs=[feedback_output, score_output, tts_output])

    return app

# Launch the app
app = verb_game()
app.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://b27173890121143a88.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b27173890121143a88.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import pandas as pd
import random
import os
import tempfile
from gtts import gTTS

# Load the irregular verbs data
data_url = "https://github.com/Hansukson/Application2/raw/main/irregular_verbs%20(1).csv"
verbs_df = pd.read_csv(data_url)

# Extract verbs data into a dictionary
verbs_data = verbs_df.set_index("present")[['past', 'p.p']].to_dict(orient="index")

def tts_play(verb_forms):
    """Generate speech for the verb forms: Present, Past, Past Participle."""
    tts_text = f"{verb_forms[0]}, {verb_forms[1]}, {verb_forms[2]}"
    temp_audio_file = tempfile.gettempdir() + "/verb_audio.mp3"
    tts = gTTS(tts_text)
    tts.save(temp_audio_file)
    return temp_audio_file

def start_game(name):
    """Welcome message when the game starts."""
    return f"Welcome, {name}! Click 'Show me a Verb' to begin.", ""

current_verb = ""
correct_count = 0
attempt_count = 0

def show_random_verb():
    """Select a random present tense verb."""
    global current_verb
    current_verb = random.choice(list(verbs_data.keys()))
    return current_verb

def check_answer(user_past, user_past_participle):
    """Check if the student's answer is correct or not."""
    global correct_count, attempt_count, current_verb

    attempt_count += 1
    correct_past, correct_past_participle = verbs_data[current_verb]['Past Tense'], verbs_data[current_verb]['Past Participle']
    audio_file = tts_play([current_verb, correct_past, correct_past_participle])

    if user_past.lower() == correct_past.lower() and user_past_participle.lower() == correct_past_participle.lower():
        correct_count += 1
        feedback = random.choice(["Amazing!", "Wonderful!", "Nice Job!"]) + f" The correct answer is: {correct_past}, {correct_past_participle}."
    else:
        feedback = f"Try again! The correct answer is: {correct_past}, {correct_past_participle}."

    score = f"Your Score: {correct_count} / {attempt_count}"
    return feedback, score, audio_file

def reset_game():
    return show_random_verb(), "", "", "", ""

# Gradio Interface
def verb_game():
    with gr.Blocks() as app:
        gr.Markdown("""# VerbMaster: Learn Irregular Verbs!
        This app helps you practice the Past and Past Participle forms of irregular verbs.
        """)

        name_input = gr.Textbox(label="Enter Your Name")
        welcome_output = gr.Textbox(label="Welcome Message", interactive=False)
        start_button = gr.Button("Start")
        start_button.click(start_game, inputs=name_input, outputs=welcome_output)

        gr.Markdown("---")
        present_verb_output = gr.Textbox(label="Present Verb", interactive=False)
        feedback_output = gr.Textbox(label="Feedback", interactive=False)
        score_output = gr.Textbox(label="Score", interactive=False)
        tts_output = gr.Audio(label="Audio Feedback")

        user_past_input = gr.Textbox(label="Enter Past Form")
        user_pp_input = gr.Textbox(label="Enter Past Participle")
        submit_button = gr.Button("Submit")
        continue_button = gr.Button("Continue")

        # Display random verb
        continue_button.click(show_random_verb, outputs=present_verb_output)

        # Check answers and show feedback, score, and sound immediately
        submit_button.click(check_answer, inputs=[user_past_input, user_pp_input],
                            outputs=[feedback_output, score_output, tts_output])

        # Continue button resets inputs and shows a new verb
        continue_button.click(reset_game, outputs=[present_verb_output, user_past_input, user_pp_input, feedback_output, score_output])

    return app

# Launch the app
app = verb_game()
app.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://5e3ba39a5e8a533fa5.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://5e3ba39a5e8a533fa5.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import pandas as pd
import random
import os
import tempfile
from gtts import gTTS

# Load the irregular verbs data
data_url = "https://github.com/Hansukson/Application2/raw/main/irregular_verbs%20(1).csv"
verbs_df = pd.read_csv(data_url)

# Extract verbs data into a dictionary
verbs_data = verbs_df.set_index("present")[['past', 'p.p']].to_dict(orient="index")

def tts_play(verb_forms):
    """Generate speech for the verb forms: Present, Past, Past Participle."""
    tts_text = f"{verb_forms[0]}, {verb_forms[1]}, {verb_forms[2]}"
    temp_audio_file = tempfile.gettempdir() + "/verb_audio.mp3"
    tts = gTTS(tts_text)
    tts.save(temp_audio_file)
    return temp_audio_file

def start_game(name):
    """Welcome message when the game starts."""
    return f"Welcome, {name}! Click 'Show me a Verb' to begin.", ""

current_verb = ""
correct_count = 0
attempt_count = 0

def show_random_verb():
    """Select a random present tense verb."""
    global current_verb
    current_verb = random.choice(list(verbs_data.keys()))
    return current_verb

def check_answer(user_past, user_past_participle):
    """Check if the student's answer is correct or not."""
    global correct_count, attempt_count, current_verb

    attempt_count += 1
    correct_past, correct_past_participle = verbs_data[current_verb]['Past Tense'], verbs_data[current_verb]['Past Participle']
    audio_file = tts_play([current_verb, correct_past, correct_past_participle])

    if user_past.lower() == correct_past.lower() and user_past_participle.lower() == correct_past_participle.lower():
        correct_count += 1
        feedback = random.choice(["Amazing!", "Wonderful!", "Nice Job!"]) + f" The correct answer is: {correct_past}, {correct_past_participle}."
    else:
        feedback = f"Try again! The correct answer is: {correct_past}, {correct_past_participle}."

    score = f"Your Score: {correct_count} / {attempt_count}"
    return feedback, score, audio_file

def reset_game():
    return show_random_verb(), "", "", "", ""

# Gradio Interface
def verb_game():
    with gr.Blocks() as app:
        gr.Markdown("""# VerbMaster: Learn Irregular Verbs!
        This app helps you practice the Past and Past Participle forms of irregular verbs.
        """)

        name_input = gr.Textbox(label="Enter Your Name")
        welcome_output = gr.Textbox(label="Welcome Message", interactive=False)
        start_button = gr.Button("Start")
        start_button.click(start_game, inputs=name_input, outputs=welcome_output)

        gr.Markdown("---")
        present_verb_output = gr.Textbox(label="Present Verb", interactive=False)
        feedback_output = gr.Textbox(label="Feedback", interactive=False)
        score_output = gr.Textbox(label="Score", interactive=False)
        tts_output = gr.Audio(label="Audio Feedback")

        user_past_input = gr.Textbox(label="Enter Past Form")
        user_pp_input = gr.Textbox(label="Enter Past Participle")
        submit_button = gr.Button("Submit")
        continue_button = gr.Button("Show me a Verb")

        # Display random verb
        continue_button.click(show_random_verb, outputs=present_verb_output)

        # Check answers and show feedback, score, and sound immediately
        submit_button.click(check_answer, inputs=[user_past_input, user_pp_input],
                            outputs=[feedback_output, score_output, tts_output])

        # Continue button resets inputs and shows a new verb
        continue_button.click(reset_game, outputs=[present_verb_output, user_past_input, user_pp_input, feedback_output, score_output])

    return app

# Launch the app
app = verb_game()
app.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://a55e85d7f2c7a15c03.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://a55e85d7f2c7a15c03.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import pandas as pd
import random
import os
import tempfile
from gtts import gTTS

# Load the irregular verbs data
data_url = "https://github.com/Hansukson/Application2/raw/main/irregular_verbs%20(1).csv"
verbs_df = pd.read_csv(data_url)

# Extract verbs data into a dictionary
verbs_data = verbs_df.set_index("present")[['past', 'p.p']].to_dict(orient="index")

def tts_play(verb_forms):
    """Generate speech for the verb forms: Present, Past, Past Participle."""
    tts_text = f"{verb_forms[0]}, {verb_forms[1]}, {verb_forms[2]}"
    temp_audio_file = tempfile.gettempdir() + "/verb_audio.mp3"
    tts = gTTS(tts_text)
    tts.save(temp_audio_file)
    return temp_audio_file

def start_game(name):
    """Welcome message when the game starts."""
    return f"Welcome, {name}! Click 'Show me a Verb' to begin."

current_verb = ""
correct_count = 0
attempt_count = 0

def show_random_verb():
    """Select a random present tense verb."""
    global current_verb
    current_verb = random.choice(list(verbs_data.keys()))
    return current_verb

def check_answer(user_past, user_past_participle):
    """Check if the student's answer is correct or not."""
    global correct_count, attempt_count, current_verb

    attempt_count += 1
    correct_past, correct_past_participle = verbs_data[current_verb]['Past Tense'], verbs_data[current_verb]['Past Participle']
    audio_file = tts_play([current_verb, correct_past, correct_past_participle])

    if user_past.lower() == correct_past.lower() and user_past_participle.lower() == correct_past_participle.lower():
        correct_count += 1
        feedback = random.choice(["Amazing!", "Wonderful!", "Nice Job!"]) + f" The correct answer is: {correct_past}, {correct_past_participle}."
    else:
        feedback = f"Try again! The correct answer is: {correct_past}, {correct_past_participle}."

    score = f"Your Score: {correct_count} / {attempt_count}"
    return feedback, score, audio_file

def reset_inputs():
    """Reset inputs for next round."""
    return "", "", ""

# Gradio Interface
def verb_game():
    with gr.Blocks() as app:
        gr.Markdown("""# VerbMaster: Learn Irregular Verbs!
        This app helps you practice the Past and Past Participle forms of irregular verbs.
        """)

        name_input = gr.Textbox(label="Enter Your Name")
        start_button = gr.Button("Start")
        welcome_output = gr.Textbox(label="Welcome Message", interactive=False)

        start_button.click(start_game, inputs=name_input, outputs=welcome_output)

        gr.Markdown("---")
        present_verb_output = gr.Textbox(label="Present Verb", interactive=False)
        feedback_output = gr.Textbox(label="Feedback", interactive=False)
        score_output = gr.Textbox(label="Score", interactive=False)
        tts_output = gr.Audio(label="Audio Feedback")

        user_past_input = gr.Textbox(label="Enter Past Form")
        user_pp_input = gr.Textbox(label="Enter Past Participle")
        submit_button = gr.Button("Submit")
        continue_button = gr.Button("Continue")

        # Show a random verb
        continue_button.click(show_random_verb, outputs=present_verb_output)

        # Check answer, give feedback, play audio, and show score
        submit_button.click(check_answer, inputs=[user_past_input, user_pp_input],
                            outputs=[feedback_output, score_output, tts_output])

        # Reset inputs and allow user to continue
        continue_button.click(reset_inputs, outputs=[user_past_input, user_pp_input, feedback_output])
        continue_button.click(show_random_verb, outputs=present_verb_output)

    return app

# Launch the app
app = verb_game()
app.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ec5d2a5785caca2d5e.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ec5d2a5785caca2d5e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import pandas as pd
import random
import os
import tempfile
from gtts import gTTS

# Load the irregular verbs data
data_url = "https://github.com/Hansukson/Application2/raw/main/irregular_verbs%20(1).csv"
verbs_df = pd.read_csv(data_url)

# Extract verbs data into a dictionary
verbs_data = verbs_df.set_index("present")[['past', 'p.p']].to_dict(orient="index")

def tts_play(verb_forms):
    """Generate speech for the verb forms: Present, Past, Past Participle."""
    tts_text = f"{verb_forms[0]}, {verb_forms[1]}, {verb_forms[2]}"
    temp_audio_file = tempfile.gettempdir() + "/verb_audio.mp3"
    tts = gTTS(tts_text)
    tts.save(temp_audio_file)
    return temp_audio_file

def start_game(name):
    """Welcome message when the game starts."""
    return f"Welcome, {name}! Click 'Show me a Verb' to begin."

current_verb = ""
correct_count = 0
attempt_count = 0

def show_random_verb():
    """Select a random present tense verb."""
    global current_verb
    current_verb = random.choice(list(verbs_data.keys()))
    return current_verb

def check_answer(user_past, user_past_participle):
    """Check if the student's answer is correct or not."""
    global correct_count, attempt_count, current_verb

    attempt_count += 1
    correct_past, correct_past_participle = verbs_data[current_verb]['Past Tense'], verbs_data[current_verb]['Past Participle']
    audio_file = tts_play([current_verb, correct_past, correct_past_participle])

    if user_past.lower() == correct_past.lower() and user_past_participle.lower() == correct_past_participle.lower():
        correct_count += 1
        feedback = random.choice(["Amazing!", "Wonderful!", "Nice Job!"]) + f" The correct answer is: {correct_past}, {correct_past_participle}."
    else:
        feedback = f"Try again! The correct answer is: {correct_past}, {correct_past_participle}."

    score = f"Your Score: {correct_count} / {attempt_count}"
    return feedback, score, audio_file

def reset_inputs():
    """Reset inputs for next round."""
    return "", "", ""

# Gradio Interface
def verb_game():
    with gr.Blocks() as app:
        gr.Markdown("""# VerbMaster: Learn Irregular Verbs!
        This app helps you practice the Past and Past Participle forms of irregular verbs.
        """)

        name_input = gr.Textbox(label="Enter Your Name")
        start_button = gr.Button("Start")
        welcome_output = gr.Textbox(label="Welcome Message", interactive=False)
        show_verb_button = gr.Button("Show me a Verb", visible=False)

        start_button.click(start_game, inputs=name_input, outputs=welcome_output)
        start_button.click(None, outputs=None, _js="() => document.querySelector('button[name=show_verb]').style.display='block'")

        gr.Markdown("---")
        present_verb_output = gr.Textbox(label="Present Verb", interactive=False)
        feedback_output = gr.Textbox(label="Feedback", interactive=False)
        score_output = gr.Textbox(label="Score", interactive=False)
        tts_output = gr.Audio(label="Audio Feedback")

        user_past_input = gr.Textbox(label="Enter Past Form")
        user_pp_input = gr.Textbox(label="Enter Past Participle")
        submit_button = gr.Button("Submit")
        continue_button = gr.Button("Continue")

        # Show a random verb when "Show me a Verb" is clicked
        show_verb_button.click(show_random_verb, outputs=present_verb_output)

        # Check answer, give feedback, play audio, and show score
        submit_button.click(check_answer, inputs=[user_past_input, user_pp_input],
                            outputs=[feedback_output, score_output, tts_output])

        # Reset inputs and allow user to continue
        continue_button.click(reset_inputs, outputs=[user_past_input, user_pp_input, feedback_output])
        continue_button.click(show_random_verb, outputs=present_verb_output)

    return app

# Launch the app
app = verb_game()
app.launch()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-f16380605da9> in <cell line: 98>()
#      96
#      97 # Launch the app
# ---> 98 app = verb_game()
#      99 app.launch()
#
# <ipython-input-16-f16380605da9> in verb_game()
#      69
#      70         start_button.click(start_game, inputs=name_input, outputs=welcome_output)
# ---> 71         start_button.click(None, outputs=None, _js="() => document.querySelector('button[name=show_verb]').style.display='block'")
#      72
#      73         gr.Markdown("---")
#
# TypeError: EventListener._setup.<locals>.event_trigger() got an unexpected keyword argument '_js'

# %%
import gradio as gr
import pandas as pd
import random
import os
import tempfile
from gtts import gTTS

# Load the irregular verbs data
data_url = "https://github.com/Hansukson/Application2/raw/main/irregular_verbs%20(1).csv"
verbs_df = pd.read_csv(data_url)

# Extract verbs data into a dictionary
verbs_data = verbs_df.set_index("present")[['past', 'p.p']].to_dict(orient="index")

def tts_play(verb_forms):
    """Generate speech for the verb forms: Present, Past, Past Participle."""
    tts_text = f"{verb_forms[0]}, {verb_forms[1]}, {verb_forms[2]}"
    temp_audio_file = tempfile.gettempdir() + "/verb_audio.mp3"
    tts = gTTS(tts_text)
    tts.save(temp_audio_file)
    return temp_audio_file

def start_game(name):
    """Welcome message when the game starts."""
    return f"Welcome, {name}! Click 'Show me a Verb' to begin.", gr.update(visible=True)

current_verb = ""
correct_count = 0
attempt_count = 0

def show_random_verb():
    """Select a random present tense verb."""
    global current_verb
    current_verb = random.choice(list(verbs_data.keys()))
    return current_verb

def check_answer(user_past, user_past_participle):
    """Check if the student's answer is correct or not."""
    global correct_count, attempt_count, current_verb

    attempt_count += 1
    correct_past, correct_past_participle = verbs_data[current_verb]['Past Tense'], verbs_data[current_verb]['Past Participle']
    audio_file = tts_play([current_verb, correct_past, correct_past_participle])

    if user_past.lower() == correct_past.lower() and user_past_participle.lower() == correct_past_participle.lower():
        correct_count += 1
        feedback = random.choice(["Amazing!", "Wonderful!", "Nice Job!"]) + f" The correct answer is: {correct_past}, {correct_past_participle}."
    else:
        feedback = f"Try again! The correct answer is: {correct_past}, {correct_past_participle}."

    score = f"Your Score: {correct_count} / {attempt_count}"
    return feedback, score, audio_file

def reset_inputs():
    """Reset inputs for next round."""
    return "", "", ""

# Gradio Interface
def verb_game():
    with gr.Blocks() as app:
        gr.Markdown("""# VerbMaster: Learn Irregular Verbs!
        This app helps you practice the Past and Past Participle forms of irregular verbs.
        """)

        name_input = gr.Textbox(label="Enter Your Name")
        start_button = gr.Button("Start")
        welcome_output = gr.Textbox(label="Welcome Message", interactive=False)
        show_verb_button = gr.Button("Show me a Verb", visible=False)

        # Button to start the game and display the "Show me a Verb" button
        start_button.click(start_game, inputs=name_input, outputs=[welcome_output, show_verb_button])

        gr.Markdown("---")
        present_verb_output = gr.Textbox(label="Present Verb", interactive=False)
        feedback_output = gr.Textbox(label="Feedback", interactive=False)
        score_output = gr.Textbox(label="Score", interactive=False)
        tts_output = gr.Audio(label="Audio Feedback")

        user_past_input = gr.Textbox(label="Enter Past Form")
        user_pp_input = gr.Textbox(label="Enter Past Participle")
        submit_button = gr.Button("Submit")
        continue_button = gr.Button("Continue")

        # Show a random verb when "Show me a Verb" is clicked
        show_verb_button.click(show_random_verb, outputs=present_verb_output)

        # Check answer, give feedback, play audio, and show score
        submit_button.click(check_answer, inputs=[user_past_input, user_pp_input],
                            outputs=[feedback_output, score_output, tts_output])

        # Reset inputs and allow user to continue
        continue_button.click(reset_inputs, outputs=[user_past_input, user_pp_input, feedback_output])
        continue_button.click(show_random_verb, outputs=present_verb_output)

    return app

# Launch the app
app = verb_game()
app.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://1de8f91f4bf9f1bf63.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://1de8f91f4bf9f1bf63.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import pandas as pd
import random
import os
import tempfile
from gtts import gTTS

# Load the irregular verbs data
data_url = "https://github.com/Hansukson/Application2/raw/main/irregular_verbs%20(1).csv"
verbs_df = pd.read_csv(data_url)

# Extract verbs data into a dictionary
verbs_data = verbs_df.set_index("present")[['past', 'p.p']].to_dict(orient="index")

def tts_play(verb_forms):
    """Generate speech for the verb forms: Present, Past, Past Participle."""
    tts_text = f"{verb_forms[0]}, {verb_forms[1]}, {verb_forms[2]}"
    temp_audio_file = tempfile.gettempdir() + "/verb_audio.mp3"
    tts = gTTS(tts_text)
    tts.save(temp_audio_file)
    return temp_audio_file

def start_game(name):
    """Welcome message when the game starts."""
    return f"Welcome, {name}! Click 'Show me a Verb' to begin.", gr.update(visible=True)

current_verb = ""
correct_count = 0
attempt_count = 0

def show_random_verb():
    """Select a random present tense verb."""
    global current_verb
    current_verb = random.choice(list(verbs_data.keys()))
    return current_verb

def check_answer(user_past, user_past_participle):
    """Check if the student's answer is correct or not."""
    global correct_count, attempt_count, current_verb

    attempt_count += 1
    correct_past, correct_past_participle = verbs_data[current_verb]['Past Tense'], verbs_data[current_verb]['Past Participle']
    audio_file = tts_play([current_verb, correct_past, correct_past_participle])

    if user_past.lower() == correct_past.lower() and user_past_participle.lower() == correct_past_participle.lower():
        correct_count += 1
        feedback = random.choice(["Amazing!", "Wonderful!", "Nice Job!"]) + f" The correct answer is: {correct_past}, {correct_past_participle}."
    else:
        feedback = f"Try again! The correct answer is: {correct_past}, {correct_past_participle}."

    score = f"Your Score: {correct_count} / {attempt_count}"
    return feedback, score, audio_file

def reset_inputs():
    """Reset inputs for next round."""
    return "", "", ""

# Gradio Interface
def verb_game():
    with gr.Blocks() as app:
        gr.Markdown("""# VerbMaster: Learn Irregular Verbs!
        This app helps you practice the Past and Past Participle forms of irregular verbs.
        """)

        name_input = gr.Textbox(label="Enter Your Name")
        start_button = gr.Button("Start")
        welcome_output = gr.Textbox(label="Welcome Message", interactive=False)
        show_verb_button = gr.Button("Show me a Verb", visible=False)

        # Button to start the game and display the "Show me a Verb" button
        start_button.click(start_game, inputs=name_input, outputs=[welcome_output, show_verb_button])

        gr.Markdown("---")
        present_verb_output = gr.Textbox(label="Present Verb", interactive=False)
        feedback_output = gr.Textbox(label="Feedback", interactive=False)
        score_output = gr.Textbox(label="Score", interactive=False)
        tts_output = gr.Audio(label="Audio Feedback")

        user_past_input = gr.Textbox(label="Enter Past Form")
        user_pp_input = gr.Textbox(label="Enter Past Participle")
        submit_button = gr.Button("Submit")
        continue_button = gr.Button("Continue")

        # Show a random verb when "Show me a Verb" is clicked
        show_verb_button.click(show_random_verb, outputs=present_verb_output)

        # Check answer, give feedback, play audio, and show score
        submit_button.click(check_answer, inputs=[user_past_input, user_pp_input],
                            outputs=[feedback_output, score_output, tts_output])

        # Reset inputs and allow user to continue
        continue_button.click(reset_inputs, outputs=[user_past_input, user_pp_input, feedback_output])
        continue_button.click(show_random_verb, outputs=present_verb_output)

    return app

# Launch the app
app = verb_game()
app.launch()
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://367f589d672e6cc854.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://367f589d672e6cc854.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
